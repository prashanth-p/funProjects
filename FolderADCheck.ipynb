# %% [markdown]
# # Access Streamlining

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import glob
import os
path="D:\\Users\\PPradee2\\Documents\\MyFolder\\access_streamling_folder_test\\results\\"
print(path)
import openpyxl
# Out:
# D:\Users\PPradee2\Documents\MyFolder\access_streamling_folder_test\results\

# %%
for fileName in glob.glob('*.xlsx'):
    # print("******************************************")
    print(fileName)
    df = pd.read_excel(fileName, sheetname='Sheet 1')
    columns = [] 
    i = 0
    # print(df.columns)
    for col in df.columns:
        columns.append(col)
    print(columns)
    
    dataForProcessing = {}
       
    for folderName in df[columns[0]].unique():
        folderName = str.strip(folderName)
        securityNames = []
        userNames = []
        for j in df[df[columns[0]]==folderName].index:
            currentSecurityName = str.strip(df[columns[1]][j])
            currentUserName = str.strip(df[columns[2]][j])
            
            if(currentSecurityName not in securityNames):
                securityNames.append(currentSecurityName)
                
            if(currentUserName not in userNames):
                userNames.append(currentUserName)
                
            dataForProcessing[folderName] = [securityNames, userNames]
    # print(dataForProcessing)
  

    processedData = {}
    processedData[columns[0]] = []
    processedData[columns[1]] = []
    processedData[columns[2]] = []
    processedData['uniqueSecurityDomains'] = []
    processedData['allGood'] = []
    
    
    for eachFolder, eachFolderSecurityAndUser in dataForProcessing.items():
        eachFolderSecurity = eachFolderSecurityAndUser[0]
        eachFolderUser = eachFolderSecurityAndUser[1]
        
        print("Folder Name: ", eachFolder)
        print("Security Domains: ", eachFolderSecurity)
        print("User Names: ", eachFolderUser)
        
        uniqueSecurityDomains = []
            # Generating Excel Sheets
        newFileName1=fileName.split(".")
        newFileName = path + newFileName1[0]+"_uniqueDomains.xlsx"
        
        for eachSecurityDomain in eachFolderSecurity:
            if(eachSecurityDomain.endswith("ADM") or eachSecurityDomain.endswith("USR")):
                print(eachSecurityDomain)
                if((eachSecurityDomain in eachFolderUser) and (eachSecurityDomain not in uniqueSecurityDomains)):
                    uniqueSecurityDomains.append(eachSecurityDomain)
        
        processedData['allGood'].append('True')    
        for eachUser in eachFolderUser:
            if(eachUser.endswith("USR") or eachUser.endswith("ADM")):
                if(eachUser not in uniqueSecurityDomains):
                    newFileName = path + "TO_CHECK_" + newFileName1[0]+"_uniqueDomains.xlsx"
                    processedData['allGood'].pop()
                    processedData['allGood'].append('False')
                    
                    
        print(uniqueSecurityDomains) 
        processedData[columns[0]].append(eachFolder)
        processedData[columns[1]].append(eachFolderSecurity)
        processedData[columns[2]].append(eachFolderUser)
        processedData['uniqueSecurityDomains'].append(uniqueSecurityDomains)
        print("**********************")
        
    # print(processedData)
    
    processedDataFrame = pd.DataFrame(processedData)
    # print(processedDataFrame)
 
    processedDataFrame.to_excel(newFileName)
# Out:
# Rep_Bigdata_LnxDev_NA.xlsx
# ['FOLDER_NAME', 'SECURITY_GROUP', 'USER_NAME']
# Folder Name:  Admin2
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  BigData_Test
# Security Domains:  ['Native']
# User Names:  ['Administrator', 'Everyone']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  EESUS_EDW
# Security Domains:  ['EESUS_EDW_DIQ_USR', 'Native']
# User Names:  ['EESUS_EDW_DIQ_USR', 'Administrator']
# EESUS_EDW_DIQ_USR
# ['EESUS_EDW_DIQ_USR']
# **********************
# Folder Name:  EESUS_EDW_SCN
# Security Domains:  ['ETHUS_ETHMIG_DIQ_USR', 'Native']
# User Names:  ['ETHUS_ETHMIG_DIQ_USR', 'Administrator']
# ETHUS_ETHMIG_DIQ_USR
# ['ETHUS_ETHMIG_DIQ_USR']
# **********************
# Folder Name:  EESUS_OPTIMIZER
# Security Domains:  ['EESUS_OPTMIZER_DIQ_USR', 'Native']
# User Names:  ['EESUS_OPTMIZER_DIQ_USR', 'Administrator']
# EESUS_OPTMIZER_DIQ_USR
# ['EESUS_OPTMIZER_DIQ_USR']
# **********************
# Folder Name:  ERP_Dashboard
# Security Domains:  ['GTSUS_ERP_Dashboard_DIQ_USR', 'Native']
# User Names:  ['ITSUS-GTSUS_ERP_Dashboard_DIQ_USR', 'Administrator']
# GTSUS_ERP_Dashboard_DIQ_USR
# []
# **********************
# Folder Name:  GTSUS_Platform_Testing
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  HCSUS_CORE_EDL_INTERFACE
# Security Domains:  ['HCSUS_CORE_DIQ_USR', 'Native']
# User Names:  ['HCSUS_CORE_DIQ_USR', 'Administrator']
# HCSUS_CORE_DIQ_USR
# ['HCSUS_CORE_DIQ_USR']
# **********************
# Folder Name:  HCS_EMS
# Security Domains:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_USR', 'Native']
# User Names:  ['HCSUS HCS_EMS_NEXT_GEN_DIQ_USR', 'Administrator']
# HCSUS_HCS_EMS_NEXT_GEN_DIQ_USR
# []
# **********************
# Folder Name:  HCS_EMS_Dev2
# Security Domains:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_USR', 'Native']
# User Names:  ['HCSUS HCS_EMS_NEXT_GEN_DIQ_USR', 'Administrator']
# HCSUS_HCS_EMS_NEXT_GEN_DIQ_USR
# []
# **********************
# Folder Name:  ITSUS_INFA_ADMIN
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JANUS_JSCEDW_DBL
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DBL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DBL_VVADDE
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL_VVADDE
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL_VVADDE
# Security Domains:  ['JANUS_JSCEDW_DIQ_USR', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_USR', 'Administrator']
# JANUS_JSCEDW_DIQ_USR
# ['JANUS_JSCEDW_DIQ_USR']
# **********************
# Folder Name:  JJCUS_CBT_DA
# Security Domains:  ['ITS-EP-APP-Informatica-Admin', 'JJCUS_JJC_CBTDA_DIQ_USR']
# User Names:  ['Admin_DJayaku1', 'JJCUS_JJC_CBTDA_DIQ_USR']
# JJCUS_JJC_CBTDA_DIQ_USR
# ['JJCUS_JJC_CBTDA_DIQ_USR']
# **********************
# Folder Name:  JJCUS_CBT_DA_SHARED
# Security Domains:  ['ITS-EP-APP-Informatica-Admin', 'JJCUS_JJC_CBTDA_DIQ_USR']
# User Names:  ['Admin_DJayaku1', 'JJCUS_JJC_CBTDA_DIQ_USR']
# JJCUS_JJC_CBTDA_DIQ_USR
# ['JJCUS_JJC_CBTDA_DIQ_USR']
# **********************
# Folder Name:  JJCUS_EFM_CORE
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  JJCUS_EFM_EDW
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  JJCUS_EFM_SHARED
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  JJCUS_EFM_SRC
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  JJCUS_GFDW_SHARED
# Security Domains:  ['JJCUS_GFDW_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_GFDW_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_GFDW_SRC_EMS_EDG
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JJCUS_GFDW_SRC_LEAPFROG
# Security Domains:  ['JJCUS_GFDW_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_GFDW_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_ITSP_INT
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_USR
# ['JJCUS_ITSP_PHASE1_DIQ_USR']
# **********************
# Folder Name:  JJCUS_ITSP_OUT
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_USR
# ['JJCUS_ITSP_PHASE1_DIQ_USR']
# **********************
# Folder Name:  JJCUS_ITSP_SHARED
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_USR
# ['JJCUS_ITSP_PHASE1_DIQ_USR']
# **********************
# Folder Name:  JJCUS_ITSP_STG
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_USR', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_USR
# ['JJCUS_ITSP_PHASE1_DIQ_USR']
# **********************
# Folder Name:  JJCUS_ITS_ASDW
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-USR
# ['JJCUS-ITS-ASDW-DIQ-USR']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_DBL
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-USR
# ['JJCUS-ITS-ASDW-DIQ-USR']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_DIL
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-USR
# ['JJCUS-ITS-ASDW-DIQ-USR']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_FXR
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-USR
# ['JJCUS-ITS-ASDW-DIQ-USR']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_SHARED
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-USR', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-USR
# ['JJCUS-ITS-ASDW-DIQ-USR']
# **********************
# Folder Name:  JJCUS_P2020_AGP_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR', 'DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# DPYUS_P2020GO_DIQ_USR
# ['DPYUS_P2020GO_DIQ_USR']
# **********************
# Folder Name:  JJCUS_P2020_AGP_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR', 'DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# DPYUS_P2020GO_DIQ_USR
# ['DPYUS_P2020GO_DIQ_USR']
# **********************
# Folder Name:  JJCUS_P2020_AGP_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR', 'DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# DPYUS_P2020GO_DIQ_USR
# ['DPYUS_P2020GO_DIQ_USR']
# **********************
# Folder Name:  JJCUS_P2020_B2B_CORE
# Security Domains:  ['JJCUS_P2020_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_P2020_B2B_SHARED
# Security Domains:  ['JJCUS_P2020_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_P2020_B2B_STG
# Security Domains:  ['JJCUS_P2020_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_P2P_B2B
# Security Domains:  ['JJCUS_FDWP2P_DIQ_USR', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_USR', 'Administrator']
# JJCUS_FDWP2P_DIQ_USR
# ['JJCUS_FDWP2P_DIQ_USR']
# **********************
# Folder Name:  JJCUS_P2P_SHARED
# Security Domains:  ['JJCUS_FDWP2P_DIQ_USR', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_USR', 'Administrator']
# JJCUS_FDWP2P_DIQ_USR
# ['JJCUS_FDWP2P_DIQ_USR']
# **********************
# Folder Name:  JJCUS_TEDW_CORE
# Security Domains:  ['JJCUS_EMW_DIQ_USR_JJCUS', 'JJCUS_EMW_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_TEDW_SHARED
# Security Domains:  ['JJCUS_EMW_DIQ_USR_JJCUS', 'JJCUS_EMW_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_TEDW_SRC_TE
# Security Domains:  ['JJCUS_EMW_DIQ_USR_JJCUS', 'JJCUS_EMW_DIQ_USR_NCSUS', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_VisualFactory_CSS
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Consumer
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Depuys
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Depuys_ToolBoss
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Ethicon
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_JJPS
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Main
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJCUS_VisualFactory_Main_Test
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_USR', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_USR
# ['ETHMX_Ethicon_VisualFactory_DIQ_USR']
# **********************
# Folder Name:  JJICA_METRICS_TOOL_DATALAKE_DWH
# Security Domains:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Native']
# User Names:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Administrator']
# JJICA-JJC_MetricsTool_DIQ_USR
# ['JJICA-JJC_MetricsTool_DIQ_USR']
# **********************
# Folder Name:  JJICA_METRICS_TOOL_DATALAKE_STG
# Security Domains:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Native']
# User Names:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Administrator']
# JJICA-JJC_MetricsTool_DIQ_USR
# ['JJICA-JJC_MetricsTool_DIQ_USR']
# **********************
# Folder Name:  JJICA_METRICS_TOOL_DWH
# Security Domains:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Native']
# User Names:  ['JJICA-JJC_MetricsTool_DIQ_USR', 'Administrator']
# JJICA-JJC_MetricsTool_DIQ_USR
# ['JJICA-JJC_MetricsTool_DIQ_USR']
# **********************
# Folder Name:  JNJSG_ASPAC_CLS_DIA_CORE
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_ASPAC_CLS_DIA_DTLK
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_ASPAC_CLS_DIA_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_ASPAC_CLS_DIA_STG
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DBL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DBL_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DIL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DIL_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DPL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DPL_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_USR', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_USR', 'Administrator']
# JNJSG_CLS_DIA_DIQ_USR
# ['JNJSG_CLS_DIA_DIQ_USR']
# **********************
# Folder Name:  JRDUS_GSDL_AG_CDC
# Security Domains:  ['JANUS-JRDUS_PRISM_DIQ_USR', 'Native']
# User Names:  ['JANUS-JRDUS_PRISM_DIQ_USR', 'Administrator']
# JANUS-JRDUS_PRISM_DIQ_USR
# ['JANUS-JRDUS_PRISM_DIQ_USR']
# **********************
# Folder Name:  JRDUS_GSDL_AG_NTT_CDC
# Security Domains:  ['JANUS-JRDUS_PRISM_DIQ_USR', 'Native']
# User Names:  ['JANUS-JRDUS_PRISM_DIQ_USR', 'Administrator']
# JANUS-JRDUS_PRISM_DIQ_USR
# ['JANUS-JRDUS_PRISM_DIQ_USR']
# **********************
# Folder Name:  JRD_RNDODW_BW
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_Core
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_DM_COM
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_DSSI_PCM
# Security Domains:  ['JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_DVL_BW
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_DataLabs
# Security Domains:  ['JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_Shareables
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_Source_Target
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_Staging
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW_Support
# Security Domains:  ['JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_Core
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_DM_COM
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_Shareables
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_Source_Target
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_Staging
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JRD_RNDODW__DVL_Testing
# Security Domains:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-RO', 'JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  JSCUS_DTBT_DBL
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_DBL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_DIL
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_DIL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_DPL
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_DPL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_DTBT_EDL
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  JSCUS_PPV_EDL
# Security Domains:  ['JAN_PPV_DIQ_USR', 'Native']
# User Names:  ['JAN_PPV_DIQ_USR', 'Administrator']
# JAN_PPV_DIQ_USR
# ['JAN_PPV_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_DWH
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_Dimensions
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_Facts
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_ODS
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_Shareables
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_Source_Target
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  PRD_BRMMM_DWH_Staging
# Security Domains:  ['Native', 'PRDUS_BRMMM_DIQ_USR']
# User Names:  ['Administrator', 'PRDUS_BRMMM_DIQ_USR']
# PRDUS_BRMMM_DIQ_USR
# ['PRDUS_BRMMM_DIQ_USR']
# **********************
# Folder Name:  iAWARE_SRC_TGT
# Security Domains:  ['JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  iAWARE_Test
# Security Domains:  ['JRD-RNDODW-DIQ-USR', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-USR', 'Administrator']
# JRD-RNDODW-DIQ-USR
# ['JRD-RNDODW-DIQ-USR']
# **********************
# Folder Name:  ~DPYUS_P2020GO_RELIAB_CORE_IAnsari3
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  ~DPYUS_P2020GO_RELIAB_STG_IAnsari3
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  ~Decommissioned_TASK000017535876_JJCUS_GBP
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  ~GLOBAL_ORTHO_SLT_DEVELOPER
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  ~JJCUS_EFM_Gbazaru
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  ~JJCUS_EFM_Nkundeti
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  ~JJCUS_EFM_Nkuruba1
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'nkuruba1', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  ~JJCUS_EFM_Pgudhka
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  ~JJCUS_EFM_Rkaswan
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_USR', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_USR', 'Administrator']
# JJCUS_JJC_EFM_DIQ_USR
# ['JJCUS_JJC_EFM_DIQ_USR']
# **********************
# Folder Name:  ~JJCUS_P2020_AGP_CORE_IAnsari3
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  ~JJCUS_P2020_AGP_STG_IAnsari3
# Security Domains:  ['DPYUS_P2020GO_DIQ_USR_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_USR', 'Administrator']
# []
# **********************
# Folder Name:  ~JSCUS_DTBT_DBL_IAnsari3
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  ~JSCUS_DTBT_DIL_IAnsari3
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  ~JSCUS_DTBT_DPL_IAnsari3
# Security Domains:  ['JJCUS_DTBT_DIQ_USR', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_USR', 'Administrator']
# JJCUS_DTBT_DIQ_USR
# ['JJCUS_DTBT_DIQ_USR']
# **********************
# Folder Name:  ~TEST_BILAL
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Rep_Bigdata_LnxProd_NA.xlsx
# ['FOLDER_NAME', 'SECURITY_GROUP', 'USER_NAME']
# Folder Name:  Admin
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  BigData_Test
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  EESUS_EDW
# Security Domains:  ['EESUS_EDW_DIQ_ADM', 'Native']
# User Names:  ['EESUS_EDW_DIQ_ADM', 'Administrator']
# EESUS_EDW_DIQ_ADM
# ['EESUS_EDW_DIQ_ADM']
# **********************
# Folder Name:  EESUS_EDW_SCN
# Security Domains:  ['ETHUS_ETHMIG_DIQ_ADM', 'Native']
# User Names:  ['ETHUS_ETHMIG_DIQ_ADM', 'Administrator']
# ETHUS_ETHMIG_DIQ_ADM
# ['ETHUS_ETHMIG_DIQ_ADM']
# **********************
# Folder Name:  EESUS_OPTIMIZER
# Security Domains:  ['EESUS_OPTMIZER_DIQ_ADM', 'Native']
# User Names:  ['EESUS_OPTMIZER_DIQ_ADM', 'Administrator']
# EESUS_OPTMIZER_DIQ_ADM
# ['EESUS_OPTMIZER_DIQ_ADM']
# **********************
# Folder Name:  HCSUS_CORE_EDL_INTERFACE
# Security Domains:  ['HCSUS_CORE_DIQ_ADM', 'Native']
# User Names:  ['HCSUS_CORE_DIQ_ADM', 'Administrator']
# HCSUS_CORE_DIQ_ADM
# ['HCSUS_CORE_DIQ_ADM']
# **********************
# Folder Name:  HCS_EMS
# Security Domains:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM_PROD', 'Native']
# User Names:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM_PROD', 'Administrator']
# []
# **********************
# Folder Name:  ITSUS_INFA_ADMIN
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JANUS_JSCEDW_DBL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DBL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_EFM_CORE
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Administrator']
# JJCUS_JJC_EFM_DIQ_ADM
# ['JJCUS_JJC_EFM_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_EFM_EDW
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Administrator']
# JJCUS_JJC_EFM_DIQ_ADM
# ['JJCUS_JJC_EFM_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_EFM_SHARED
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Administrator']
# JJCUS_JJC_EFM_DIQ_ADM
# ['JJCUS_JJC_EFM_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_EFM_SRC
# Security Domains:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_JJC_EFM_DIQ_ADM', 'Administrator']
# JJCUS_JJC_EFM_DIQ_ADM
# ['JJCUS_JJC_EFM_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_ITSP_INT
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_ADM
# ['JJCUS_ITSP_PHASE1_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_ITSP_OUT
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_ADM
# ['JJCUS_ITSP_PHASE1_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_ITSP_SHARED
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_ADM
# ['JJCUS_ITSP_PHASE1_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_ITSP_STG
# Security Domains:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_ITSP_PHASE1_DIQ_ADM', 'Administrator']
# JJCUS_ITSP_PHASE1_DIQ_ADM
# ['JJCUS_ITSP_PHASE1_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_ITS_ASDW
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-ADM
# ['JJCUS-ITS-ASDW-DIQ-ADM']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_DBL
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-ADM
# ['JJCUS-ITS-ASDW-DIQ-ADM']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_DIL
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-ADM
# ['JJCUS-ITS-ASDW-DIQ-ADM']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_FXR
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-ADM
# ['JJCUS-ITS-ASDW-DIQ-ADM']
# **********************
# Folder Name:  JJCUS_ITS_ASDW_SHARED
# Security Domains:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Native']
# User Names:  ['JJCUS-ITS-ASDW-DIQ-ADM', 'JJCUS-ITS-ASDW-DIQ-RO', 'Administrator']
# JJCUS-ITS-ASDW-DIQ-ADM
# ['JJCUS-ITS-ASDW-DIQ-ADM']
# **********************
# Folder Name:  JJCUS_P2020_AGP_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_AGP_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_AGP_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# DPYUS_P2020GO_DIQ_ADM
# ['DPYUS_P2020GO_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_B2B_CORE
# Security Domains:  ['JJCUS_P2020_DIQ_DQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_DQ', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_P2020_B2B_SHARED
# Security Domains:  ['JJCUS_P2020_DIQ_DQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_DQ', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_P2020_B2B_STG
# Security Domains:  ['JJCUS_P2020_DIQ_DQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_DQ', 'Administrator']
# []
# **********************
# Folder Name:  JJCUS_TEDW_CORE
# Security Domains:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_ADM_JJCUS', 'JJCUS_EMW_DIQ_ADM_NCSUS', 'JJCUS_EMW_DIQ_RO', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_RO', 'Administrator']
# JJCUS_EMW_DIQ_ADM
# ['JJCUS_EMW_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_TEDW_SHARED
# Security Domains:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_ADM_JJCUS', 'JJCUS_EMW_DIQ_ADM_NCSUS', 'JJCUS_EMW_DIQ_RO', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_RO', 'Administrator']
# JJCUS_EMW_DIQ_ADM
# ['JJCUS_EMW_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_TEDW_SRC_TE
# Security Domains:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_ADM_JJCUS', 'JJCUS_EMW_DIQ_ADM_NCSUS', 'JJCUS_EMW_DIQ_RO', 'Native']
# User Names:  ['JJCUS_EMW_DIQ_ADM', 'JJCUS_EMW_DIQ_RO', 'Administrator']
# JJCUS_EMW_DIQ_ADM
# ['JJCUS_EMW_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Consumer
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Depuys
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Depuys_ToolBoss
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Ethicon
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_JJPS
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Main
# Security Domains:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Native']
# User Names:  ['ETHMX_Ethicon_VisualFactory_DIQ_ADM', 'Administrator']
# ETHMX_Ethicon_VisualFactory_DIQ_ADM
# ['ETHMX_Ethicon_VisualFactory_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_VisualFactory_Main_BKP
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JJICA_METRICS_TOOL_DWH
# Security Domains:  ['NCSUS-JJC_MetricsTool_DIQ_DQ', 'Native']
# User Names:  ['NCSUS-JJC_MetricsTool_DIQ_DQ', 'Administrator']
# []
# **********************
# Folder Name:  JNJSG_CLS_DIA_DBL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Administrator']
# JNJSG_CLS_DIA_DIQ_ADM
# ['JNJSG_CLS_DIA_DIQ_ADM']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DBL_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Administrator']
# JNJSG_CLS_DIA_DIQ_ADM
# ['JNJSG_CLS_DIA_DIQ_ADM']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DIL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Administrator']
# JNJSG_CLS_DIA_DIQ_ADM
# ['JNJSG_CLS_DIA_DIQ_ADM']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DIL_SHARED
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Administrator']
# JNJSG_CLS_DIA_DIQ_ADM
# ['JNJSG_CLS_DIA_DIQ_ADM']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DPL
# Security Domains:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Native']
# User Names:  ['JNJSG_CLS_DIA_DIQ_ADM', 'Administrator']
# JNJSG_CLS_DIA_DIQ_ADM
# ['JNJSG_CLS_DIA_DIQ_ADM']
# **********************
# Folder Name:  JNJSG_CLS_DIA_DPL_SHARED
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JRD_RNDODW_BW
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_Core
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_DM_COM
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_DSSI_PCM
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_Shareables
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_Source_Target
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JRD_RNDODW_Staging
# Security Domains:  ['JRD-RNDODW-DIQ-ADM', 'Native']
# User Names:  ['JRD-RNDODW-DIQ-ADM', 'Administrator']
# JRD-RNDODW-DIQ-ADM
# ['JRD-RNDODW-DIQ-ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DBL
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DBL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DIL
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DIL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DPL
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_DTBT_DPL_SHARED
# Security Domains:  ['JJCUS_DTBT_DIQ_ADM', 'Native']
# User Names:  ['JJCUS_DTBT_DIQ_ADM', 'Administrator']
# JJCUS_DTBT_DIQ_ADM
# ['JJCUS_DTBT_DIQ_ADM']
# **********************
# Rep_Bigdata_LnxQA_NA.xlsx
# ['FOLDER_NAME', 'SECURITY_GROUP', 'USER_NAME']
# Folder Name:  BigData_Test
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_FIDELITY_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_CORE
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_DTLK
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_SHARED
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  DPYUS_P2020GO_RELIAB_ANALYTICS_STG
# Security Domains:  ['DPYUS_P2020GO_DIQ_ADM_JJCUS', 'DPYUS_P2020GO_DIQ_ADM_NCSUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['DPYUS_P2020GO_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  EESUS_EDW
# Security Domains:  ['EESUS_EDW_DIQ_ADM', 'Native']
# User Names:  ['EESUS_EDW_DIQ_ADM', 'Administrator']
# EESUS_EDW_DIQ_ADM
# ['EESUS_EDW_DIQ_ADM']
# **********************
# Folder Name:  EESUS_EDW_SCN
# Security Domains:  ['ETHUS_ETHMIG_DIQ_ADM', 'Native']
# User Names:  ['ETHUS_ETHMIG_DIQ_ADM', 'Administrator']
# ETHUS_ETHMIG_DIQ_ADM
# ['ETHUS_ETHMIG_DIQ_ADM']
# **********************
# Folder Name:  EESUS_OPTIMIZER
# Security Domains:  ['EESUS_OPTMIZER_DIQ_ADM', 'Native']
# User Names:  ['EESUS_OPTMIZER_DIQ_ADM', 'Administrator']
# EESUS_OPTMIZER_DIQ_ADM
# ['EESUS_OPTMIZER_DIQ_ADM']
# **********************
# Folder Name:  ERP_Dashboard
# Security Domains:  ['GTSUS_ERP_Dashboard_DIQ_ADM', 'JJCUS_ITSP_PHASE1_DIQ_ADM', 'Native']
# User Names:  ['ITSUS-GTSUS_ERP_Dashboard_DIQ_ADM', 'JJCUS_ITSP_PHASE1_DIQ_ADM', 'Administrator']
# GTSUS_ERP_Dashboard_DIQ_ADM
# JJCUS_ITSP_PHASE1_DIQ_ADM
# ['JJCUS_ITSP_PHASE1_DIQ_ADM']
# **********************
# Folder Name:  GTSUS_Platform_Testing
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  HCSUS_CORE_EDL_INTERFACE
# Security Domains:  ['HCSUS_CORE_DIQ_ADM', 'Native']
# User Names:  ['HCSUS_CORE_DIQ_ADM', 'Administrator']
# HCSUS_CORE_DIQ_ADM
# ['HCSUS_CORE_DIQ_ADM']
# **********************
# Folder Name:  HCS_EMS
# Security Domains:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM', 'Native']
# User Names:  ['HCSUS HCS_EMS_NEXT_GEN_DIQ_ADM', 'Administrator']
# HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM
# []
# **********************
# Folder Name:  HCS_EMS_QA2
# Security Domains:  ['HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM', 'Native']
# User Names:  ['HCSUS HCS_EMS_NEXT_GEN_DIQ_ADM', 'Administrator']
# HCSUS_HCS_EMS_NEXT_GEN_DIQ_ADM
# []
# **********************
# Folder Name:  ITSUS_INFA_ADMIN
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  JANUS_JSCEDW_DBL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DBL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DIL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JANUS_JSCEDW_DPL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# ...
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_SAP_ISRAEL_STG
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_SAP_ISRAEL_STG_DEV
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_SAP_MARS_STG
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_SAP_USROTC_STG
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_CRDUS', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_STG
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_ASPUS', 'JJCUS_P2020_DIQ_ADM_CNTUS', 'JJCUS_P2020_DIQ_ADM_CRDUS', 'JJCUS_P2020_DIQ_ADM_DPYUS', 'JJCUS_P2020_DIQ_ADM_HCSUS', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2020_PLAN_ANALYTICS_STG_SHARED
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_ASPUS', 'JJCUS_P2020_DIQ_ADM_CNTUS', 'JJCUS_P2020_DIQ_ADM_CRDUS', 'JJCUS_P2020_DIQ_ADM_DPYUS', 'JJCUS_P2020_DIQ_ADM_HCSUS', 'JJCUS_P2020_DIQ_ADM_JJCUS', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_1X_CORE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_1X_STG
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_ACAR
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_AP
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_ARB_NPFM
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_ARIBA_EMEA
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_ARIBA_NON_EMEA
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_ATLAS
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_BASE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_CONSUMER
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_DATA_PULSE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_DIVESTITURE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_EU2
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_GSDB
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_INVOICE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_LPFG
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_MATERIAL
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_PANDA
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_PURCHASE
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_SHARED
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_SUPPLIER
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_SUPPLIER_DIVERSITY
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'JJCUS_FDWP2P_DIQ_RO', 'JJCUS_FDWP2P_DIQ_RO_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_RO', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJCUS_P2P_SUSTAIN
# Security Domains:  ['JJCUS_FDWP2P_DIQ_ADM', 'JJCUS_FDWP2P_DIQ_ADM_JJCUS', 'JJCUS_FDWP2P_DIQ_ADM_NCSBR', 'JJCUS_FDWP2P_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_FDWP2P_DIQ_ADM', 'Administrator']
# JJCUS_FDWP2P_DIQ_ADM
# ['JJCUS_FDWP2P_DIQ_ADM']
# **********************
# Folder Name:  JJSC_PRSM_SCRCRD
# Security Domains:  ['JJCUS-JJSC_PRISM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS-JJSC_PRISM_DIQ_ADM', 'Administrator']
# JJCUS-JJSC_PRISM_DIQ_ADM
# ['JJCUS-JJSC_PRISM_DIQ_ADM']
# **********************
# Folder Name:  JJSC_PRSM_SCRCRD_SHARED
# Security Domains:  ['JJCUS-JJSC_PRISM_DIQ_ADM', 'Native']
# User Names:  ['JJCUS-JJSC_PRISM_DIQ_ADM', 'Administrator']
# JJCUS-JJSC_PRISM_DIQ_ADM
# ['JJCUS-JJSC_PRISM_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_ABS
# Security Domains:  ['ITS_ABS_DIQ_ADM', 'Native']
# User Names:  ['ITS_ABS_DIQ_ADM', 'Administrator']
# ITS_ABS_DIQ_ADM
# ['ITS_ABS_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_ABS_SHARED
# Security Domains:  ['ITS_ABS_DIQ_ADM', 'Native']
# User Names:  ['ITS_ABS_DIQ_ADM', 'Administrator']
# ITS_ABS_DIQ_ADM
# ['ITS_ABS_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DBL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DBL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DIL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DPL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_DPL_SHARED
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_INV_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_LP
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_CRDUS', 'JANUS_JSCEDW_DIQ_ADM_JANUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_LFSUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_NCAA_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_PKU
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM', 'JANUS_JSCEDW_DIQ_ADM_CNTUS', 'JANUS_JSCEDW_DIQ_ADM_JJCUS', 'JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# JANUS_JSCEDW_DIQ_ADM
# ['JANUS_JSCEDW_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_PLN_DIL
# Security Domains:  ['JANUS_JSCEDW_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JANUS_JSCEDW_DIQ_ADM', 'Administrator']
# []
# **********************
# Folder Name:  JSCUS_JSCEDW_PPV
# Security Domains:  ['ITS_ABS_DIQ_ADM', 'Native']
# User Names:  ['ITS_ABS_DIQ_ADM', 'Administrator']
# ITS_ABS_DIQ_ADM
# ['ITS_ABS_DIQ_ADM']
# **********************
# Folder Name:  JSCUS_JSCEDW_PPV_SHARED
# Security Domains:  ['ITS_ABS_DIQ_ADM', 'Native']
# User Names:  ['ITS_ABS_DIQ_ADM', 'Administrator']
# ITS_ABS_DIQ_ADM
# ['ITS_ABS_DIQ_ADM']
# **********************
# Folder Name:  RNDUS_PDW_PHARMA
# Security Domains:  ['Native', 'RNDUS_PDW_DIQ_ADM', 'RNDUS_PDW_DIQ_ADM_RNDUS']
# User Names:  ['Administrator', 'RNDUS_PDW_DIQ_ADM']
# RNDUS_PDW_DIQ_ADM
# ['RNDUS_PDW_DIQ_ADM']
# **********************
# Folder Name:  Test_Connections_P2020
# Security Domains:  ['JJCUS_P2020_DIQ_ADM', 'JJCUS_P2020_DIQ_ADM_NCSUS', 'Native']
# User Names:  ['JJCUS_P2020_DIQ_ADM', 'Administrator']
# JJCUS_P2020_DIQ_ADM
# ['JJCUS_P2020_DIQ_ADM']
# **********************
# Folder Name:  ~SParamas
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
# Folder Name:  ~~kvasudev
# Security Domains:  ['Native']
# User Names:  ['Administrator']
# []
# **********************
